# %%
import pandas as pd
import numpy as np
from pymongo import MongoClient

# %matplotlib inline

mongo_client = MongoClient('18.236.138.158', 27016)
database_reference = mongo_client.twitter

# %%
from mongo_aggregation_verbs import *

# %%
database_reference.collection_names()
# Out:
# ['users', 'instructor_test_group', 'tweets']

# %%
collection_reference = database_reference.instructor_test_group

# %%
collection_reference.count()
# Out:
# 20000

# %%
source_is_instagram = { 'source' : '<a href="http://instagram.com" rel="nofollow">Instagram</a>' } #instagram http
source_is_not_instagram = { 'source' : {'$ne' : '<a href="http://instagram.com" rel="nofollow">Instagram</a>'} }

# %%
(collection_reference.find(source_is_instagram).count(),
 collection_reference.find(source_is_not_instagram).count())
# Out:
# (1907, 18093)

# %% [markdown]
# ## Tweet Locations

# %%
not_null = { '$ne' : None }
nonnull_geo = {'geo' : not_null }
keep_geo_and_text = { 'geo' : 1, 'text' : 1 , '_id' : 0}

match_insta = {
    MATCH : source_is_instagram
}

match_not_insta = {
    MATCH : source_is_not_instagram
}

# %%
cursor = collection_reference.aggregate([
    { MATCH : source_is_instagram },
    { MATCH : nonnull_geo},
    { COUNT : "geo"}
])
next(cursor)
# Out:
# {'geo': 1907}

# %%
cursor = collection_reference.aggregate([
    { MATCH : source_is_not_instagram },
    { MATCH : nonnull_geo},
    { COUNT : "geo"}
])
next(cursor)
# Out:
# {'geo': 1045}

# %%
def group_and_count(key):
    return { GROUP : {
                 "_id"   : key,
                 "count" : { "$sum" : 1 }
                }
           }

# %%
def parse_geo_from_tweets(tweets):
    tweets = pd.DataFrame(tweets)
    geo = pd.DataFrame(list(tweets['_id'].values))
    geo['count'] = tweets['count']
    return geo

# %%
cursor = collection_reference.aggregate([
    { MATCH : source_is_not_instagram },
    { MATCH : nonnull_geo},
    group_and_count('$geo'),
    { MATCH : { "count" : { "$gt" : 14 } } }, 
    { SORT  : { "count" : -1 } }
])
not_insta = parse_geo_from_tweets(list(cursor))
not_insta
# Out:
#                   coordinates   type  count
# 0  [34.0522342, -118.2436849]  Point    206
# 1  [37.3813444, -122.1802812]  Point     39
# 2   [34.1425078, -118.255075]  Point     31
# 3   [36.778261, -119.4179324]  Point     21
# 4        [35.426667, -116.89]  Point     17
# 5   [34.0508369, -118.263032]  Point     16
# 6  [34.0194543, -118.4911912]  Point     15

# %%
cursor = collection_reference.aggregate([
    { MATCH : source_is_instagram },
    { MATCH : nonnull_geo},
    group_and_count('$geo'),
    { MATCH : { "count" : { "$gt" : 14 } } }, 
    { SORT  : { "count" : -1 } }
])
insta = parse_geo_from_tweets(list(cursor))
insta
# Out:
#                     coordinates   type  count
# 0           [34.0522, -118.243]  Point    465
# 1  [36.48863024, -119.72972051]  Point     37
# 2  [34.09799334, -118.33866453]  Point     35
# 3  [34.07305556, -118.39944444]  Point     29
# 4           [34.0221, -118.481]  Point     27
# 5    [34.0402214, -118.2545227]  Point     16
# 6    [33.9442368, -118.3975983]  Point     15

# %%
import folium
starting_loc = [34.0689, -118.4452]
la_map = folium.Map(location=starting_loc, zoom_start=12)

# %%
for loc, count in not_insta[['coordinates','count']].values:
    popup = folium.Popup(str(count), parse_html=True)
    folium.Marker(loc, popup=popup, icon=folium.Icon(color='red')).add_to(la_map)
for loc, count in insta[['coordinates','count']].values:
    popup = folium.Popup(str(count), parse_html=True)
    folium.Marker(loc, popup=popup, icon=folium.Icon(color='blue')).add_to(la_map)

# %%
la_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
def parse_geo_from_tweets(tweets):
    tweets = pd.DataFrame(tweets)
    geo = pd.DataFrame(list(tweets['_id'].values))
    geo['count'] = tweets['count']
    return geo

# %%
#top 10 not instagram users in terms of twitter using. 
cursor = collection_reference.aggregate([
    { MATCH : source_is_not_instagram },
    { MATCH : nonnull_geo},
    group_and_count('$user.id'),
    { MATCH : { "count" : { "$gt" : 14 } } }, 
    { SORT  : { "count" : -1 } },
    { LIMIT : 10 }
])
not_insta_top_users = pd.DataFrame(list(cursor))
not_insta_top_users
# Out:
#           _id  count
# 0  4549072827     29
# 1   787687147     29
# 2  1414684496     27
# 3  3066057658     27
# 4   789990810     27
# 5  4191239027     25
# 6    21298660     21
# 7  3864064936     19
# 8    21298373     19
# 9  3380828067     17

# %%
cursor = collection_reference.aggregate([
    { MATCH : source_is_instagram },
    { MATCH : nonnull_geo},
    group_and_count('$user.id'),
#     { MATCH : { "count" : { "$gt" : 10 } } }, 
    { SORT  : { "count" : -1 } },
    { LIMIT : 10 }
])
insta_top_users = pd.DataFrame(list(cursor))
insta_top_users
# Out:
#                   _id  count
# 0          1455659006     10
# 1           613833206      8
# 2  843390093012353024      6
# 3          4561143733      6
# 4            19640448      5
# 5           226456467      5
# 6            37016954      4
# 7  760160463833313280      4
# 8            30723561      4
# 9          2267807461      4

# %%
not_insta_top_users_ids = not_insta_top_users._id.values
insta_top_users_ids = insta_top_users._id.values

# %%
not_insta_top_users_ids_list = list(not_insta_top_users_ids)
not_insta_top_users_ids_list = [int(i) for i in not_insta_top_users_ids_list]
insta_top_users_ids_list = list(insta_top_users_ids)
insta_top_users_ids_list = [int(i) for i in insta_top_users_ids_list]

# %%
def parse_geo_from_tweets(tweets):
    tweets = pd.DataFrame(tweets)
    tmp = pd.DataFrame(list(tweets['_id'].values))
    geo = pd.DataFrame(list(tmp['geo'].values))
    geo['user_id'] = tmp['user_id']
    geo['count'] = tweets['count']
    return geo

# %%
cursor = collection_reference.aggregate([
    { MATCH : source_is_not_instagram },
    { MATCH : nonnull_geo},
    { PROJECT : { "user_id" : "$user.id", "geo" : 1, "text" : 1, "_id" :0 } },
    { MATCH : { "user_id" : { "$in" : not_insta_top_users_ids_list }}},
    group_and_count({"user_id" : "$user_id", "geo" : "$geo"}),
])

not_insta_top_user_geo = parse_geo_from_tweets(list(cursor))

# %%
cursor = collection_reference.aggregate([
    { MATCH : source_is_instagram },
    { MATCH : nonnull_geo},
    { PROJECT : { "user_id" : "$user.id", "geo" : 1, "text" : 1, "_id" :0 } },
    { MATCH : { "user_id" : { "$in" : insta_top_users_ids_list }}},
    group_and_count({"user_id" : "$user_id", "geo" : "$geo"}),
])
insta_top_user_geo = parse_geo_from_tweets(list(cursor))

# %%
not_insta_top_user_geo.head()
# Out:
#                     coordinates   type     user_id  count
# 0  [34.19743613, -118.58178967]  Point  4549072827      1
# 1        [34.03491, -118.27746]  Point  4191239027      1
# 2     [35.7476654, -118.060997]  Point  1414684496      1
# 3         [34.0995, -118.32813]  Point  4191239027      1
# 4     [34.187044, -118.3812562]  Point   789990810      1

# %%
insta_top_user_geo.head()
# Out:
#                     coordinates   type     user_id  count
# 0  [34.04453451, -118.26677639]  Point   226456467      1
# 1  [34.06895637, -118.40267947]  Point  1455659006      1
# 2           [34.0221, -118.481]  Point  1455659006      1
# 3  [34.07305556, -118.39944444]  Point  1455659006      5
# 4  [34.08718311, -118.46354276]  Point    19640448      1

# %%
colors_not_insta = {
    4549072827 : 'red',
    3066057658 : 'blue',
    1414684496 : 'green',
    21298660 : 'purple',
    3380828067 : 'orange',
    787687147 : 'darkred',
    21298373 : 'lightred',
    3864064936 : 'beige',
    4191239027 : 'darkblue',
    789990810 : 'darkgreen',
}

# colors_insta = {
#     760160463833313280 : '#0000ff',
#     30723561 : '#0010ff',
#     613833206 : '#0020ff',
#     2267807461 : '#0030ff',
#     4561143733 : '#0040ff',
#     1455659006 : '#0050ff',
#     37016954 : '#0060ff',
#     19640448 : '#0070ff',
#     843390093012353024 : '#0080ff',
#     226456467 : '#0090ff',
# }

# %%
not_insta_top_user_geo['color'] = not_insta_top_user_geo.user_id.apply(lambda x: colors_not_insta[x])
# insta_top_user_geo['color'] = insta_top_user_geo.user_id.apply(lambda x: colors_insta[x])

# %%
not_insta_top_user_geo.sample(10)
# Out:
#                     coordinates   type     user_id  count      color
# 112  [33.9850469, -118.4694832]  Point   789990810      1  darkgreen
# 18   [38.7841682, -122.7385025]  Point  1414684496      1      green
# 75       [34.03453, -118.31303]  Point  4191239027      1   darkblue
# 89       [34.04821, -118.29924]  Point  4191239027      1   darkblue
# 43   [38.7985001, -122.7646637]  Point  1414684496      1      green
# 9        [34.17288, -118.48278]  Point  4191239027      1   darkblue
# 63   [34.0617664, -118.4447863]  Point    21298660      1     purple
# 7        [34.09425, -118.30502]  Point  4191239027      1   darkblue
# 54   [37.6346664, -119.0261688]  Point  1414684496      1      green
# 91   [34.2007012, -118.5670141]  Point  4549072827      1        red

# %%
starting_loc = [34.0689, -118.4452]
la_map = folium.Map(location=starting_loc, zoom_start=12)

# %%
for loc, color, count in not_insta_top_user_geo[['coordinates','color','count']].values:
    popup = folium.Popup(str(count), parse_html=True)
    if count < 3:
        folium.Marker(loc, popup=popup, icon=folium.Icon(color=color)).add_to(la_map)
#     else:
#         folium.Marker(loc, popup=popup, icon=folium.Icon(color=color, icon='warning')).add_to(la_map)
# for loc, count in insta[['coordinates','count']].values:
#     folium.Marker(loc, popup=popup, icon=folium.Icon(color='blue')).add_to(la_map)

# %%
la_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
cur = collection_reference.find({"user.id" : 1414684496})

# %%
tw = list(cur)

# %%
pd.DataFrame(tw)
# Out:
#                          _id contributors  \
# 0   5a6e640336dd5f000169666a         None
# 1   5a5464b247b2a100b5089689         None
# 2   5a532aa247b2a100b507c97d         None
# 3   5a77660615ba4c0001556e66         None
# 4   5a70e57e36dd5f00016aecf2         None
# 5   5a5704e236dd5f00015bac38         None
# 6   5a69afca36dd5f000166c852         None
# 7   5a7ccd1315ba4c000158eed8         None
# 8   5a7b456f15ba4c000157ec4b         None
# 9   5a52f13647b2a100b5079d74         None
# 10  5a778e1b15ba4c00015591e0         None
# 11  5a56daee36dd5f00015b8a2a         None
# 12  5a63544936dd5f000162ddff         None
# 13  5a7b129315ba4c000157ca9e         None
# 14  5a70d5cb36dd5f00016ae098         None
# 15  5a707bca36dd5f00016aa59f         None
# 16  5a79235615ba4c000156c1cb         None
# 17  5a73c5aa36dd5f00016cca8d         None
# 18  5a5c893a36dd5f00015ee9be         None
# 19  5a66ef4436dd5f0001652a02         None
# 20  5a72f2f636dd5f00016c4931         None
# 21  5a59379e36dd5f00015ced33         None
# 22  5a63579136dd5f000162def3         None
# 23  5a52f17247b2a100b5079db1         None
# 24  5a7860ce15ba4c0001563a9d         None
# 25  5a70d24636dd5f00016addaf         None
# 26  5a763a0615ba4c000154d12f         None
#
#                                           coordinates  \
# 0   {'type': 'Point', 'coordinates': [-119.0261688...
# 1   {'type': 'Point', 'coordinates': [-116.6846667...
# 2   {'type': 'Point', 'coordinates': [-116.8243333...
# 3   {'type': 'Point', 'coordinates': [-122.8183365...
# 4   {'type': 'Point', 'coordinates': [-122.7996674...
# 5   {'type': 'Point', 'coordinates': [-122.7646637...
# 6   {'type': 'Point', 'coordinates': [-117.4976654...
# 7   {'type': 'Point', 'coordinates': [-122.8151703...
# 8   {'type': 'Point', 'coordinates': [-116.0821686...
# 9   {'type': 'Point', 'coordinates': [-118.9056702...
# 10  {'type': 'Point', 'coordinates': [-116.7894974...
# 11  {'type': 'Point', 'coordinates': [-118.8724976...
# 12  {'type': 'Point', 'coordinates': [-122.8225021...
# 13  {'type': 'Point', 'coordinates': [-122.8171692...
# 14  {'type': 'Point', 'coordinates': [-117.426, 36...
# 15  {'type': 'Point', 'coordinates': [-122.8111649...
# 16  {'type': 'Point', 'coordinates': [-117.4195, 3...
# 17  {'type': 'Point', 'coordinates': [-118.8789978...
# 18  {'type': 'Point', 'coordinates': [-122.7478333...
# 19  {'type': 'Point', 'coordinates': [-118.8335037...
# 20  {'type': 'Point', 'coordinates': [-122.7626648...
# 21  {'type': 'Point', 'coordinates': [-121.3199997...
# 22  {'type': 'Point', 'coordinates': [-117.7256699...
# 23  {'type': 'Point', 'coordinates': [-122.7385025...
# 24  {'type': 'Point', 'coordinates': [-115.4329987...
# 25  {'type': 'Point', 'coordinates': [-116.998497,...
# 26  {'type': 'Point', 'coordinates': [-118.060997,...
#
#                         created_at  \
# 0   Mon Jan 29 00:00:03 +0000 2018
# 1   Tue Jan 09 06:44:02 +0000 2018
# 2   Mon Jan 08 08:24:02 +0000 2018
# 3   Sun Feb 04 19:59:01 +0000 2018
# 4   Tue Jan 30 21:37:02 +0000 2018
# 5   Thu Jan 11 06:32:02 +0000 2018
# 6   Thu Jan 25 10:22:01 +0000 2018
# 7   Thu Feb 08 22:20:02 +0000 2018
# 8   Wed Feb 07 18:29:03 +0000 2018
# 9   Mon Jan 08 04:19:02 +0000 2018
# 10  Sun Feb 04 22:50:01 +0000 2018
# 11  Thu Jan 11 03:33:02 +0000 2018
# 12  Sat Jan 20 14:38:01 +0000 2018
# 13  Wed Feb 07 14:52:02 +0000 2018
# 14  Tue Jan 30 20:30:02 +0000 2018
# 15  Tue Jan 30 14:06:02 +0000 2018
# 16  Tue Feb 06 03:39:02 +0000 2018
# 17  Fri Feb 02 01:58:02 +0000 2018
# 18  Mon Jan 15 10:58:02 +0000 2018
# 19  Tue Jan 23 08:16:03 +0000 2018
# 20  Thu Feb 01 10:59:02 +0000 2018
# 21  Fri Jan 12 22:33:02 +0000 2018
# 22  Sat Jan 20 14:52:01 +0000 2018
# 23  Mon Jan 08 04:20:02 +0000 2018
# 24  Mon Feb 05 13:49:01 +0000 2018
# 25  Tue Jan 30 20:15:02 +0000 2018
# 26  Sat Feb 03 22:39:01 +0000 2018
#
#                                              entities  favorite_count  \
# 0   {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 1   {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 2   {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 3   {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 4   {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 5   {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 6   {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 7   {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 8   {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 9   {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 10  {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 11  {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 12  {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 13  {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 14  {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 15  {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 16  {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 17  {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 18  {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 19  {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 20  {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 21  {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 22  {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 23  {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 24  {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 25  {'hashtags': [{'text': 'earthquake', 'indices'...               0
# 26  {'hashtags': [{'text': 'earthquake', 'indices'...               0
#
#    favorited filter_level                                                geo  \
# 0      False          low  {'type': 'Point', 'coordinates': [37.6346664, ...
# 1      False          low  {'type': 'Point', 'coordinates': [33.6255, -11...
# 2      False          low  {'type': 'Point', 'coordinates': [33.568, -116...
# 3      False          low  {'type': 'Point', 'coordinates': [38.8153343, ...
# 4      False          low  {'type': 'Point', 'coordinates': [38.8264999, ...
# 5      False          low  {'type': 'Point', 'coordinates': [38.7985001, ...
# 6      False          low  {'type': 'Point', 'coordinates': [33.7456665, ...
# 7      False          low  {'type': 'Point', 'coordinates': [38.821167, -...
# 8      False          low  {'type': 'Point', 'coordinates': [33.7556648, ...
# 9      False          low  {'type': 'Point', 'coordinates': [37.6741676, ...
# 10     False          low  {'type': 'Point', 'coordinates': [33.4906654, ...
# 11     False          low  {'type': 'Point', 'coordinates': [37.658165, -...
# 12     False          low  {'type': 'Point', 'coordinates': [38.8149986, ...
# 13     False          low  {'type': 'Point', 'coordinates': [38.8105011, ...
# 14     False          low  {'type': 'Point', 'coordinates': [36.9158333, ...
# 15     False          low  {'type': 'Point', 'coordinates': [38.7988319, ...
# 16     False          low  {'type': 'Point', 'coordinates': [33.5155, -11...
# 17     False          low  {'type': 'Point', 'coordinates': [37.652832, -...
# 18     False          low  {'type': 'Point', 'coordinates': [38.7734985, ...
# 19     False          low  {'type': 'Point', 'coordinates': [37.5778351, ...
# 20     False          low  {'type': 'Point', 'coordinates': [38.7966652, ...
# 21     False          low  {'type': 'Point', 'coordinates': [36.6941681, ...
# 22     False          low  {'type': 'Point', 'coordinates': [36.0496674, ...
# 23     False          low  {'type': 'Point', 'coordinates': [38.7841682, ...
# 24     False          low  {'type': 'Point', 'coordinates': [32.7511673, ...
# 25     False          low  {'type': 'Point', 'coordinates': [33.4403343, ...
# 26     False          low  {'type': 'Point', 'coordinates': [35.7476654, ...
#
#                     id                        ...                          \
# 0   957765246336172033                        ...
# 1   950619154695909376                        ...
# 2   950281931865731074                        ...
# 3   960241303769399296                        ...
# 4   958454029066973184                        ...
# 5   951340908959551488                        ...
# 6   956472218208256001                        ...
# 7   961726343133081600                        ...
# 8   961305824005054465                        ...
# 9   950220274464522241                        ...
# 10  960284337106165760                        ...
# 11  951295861585199104                        ...
# 12  954724702869598209                        ...
# 13  961251212069781506                        ...
# 14  958437168065605632                        ...
# 15  958340531507130369                        ...
# 16  960719456589692928                        ...
# 17  959244486571257856                        ...
# 18  952857402642083841                        ...
# 19  955715742246121473                        ...
# 20  959018245343797249                        ...
# 21  951945141773746176                        ...
# 22  954728225590067200                        ...
# 23  950220527305543680                        ...
# 24  960510577113092097                        ...
# 25  958433392483188736                        ...
# 26  959919181142532096                        ...
#
#    possibly_sensitive quote_count reply_count retweet_count retweeted  \
# 0               False           0           0             0     False
# 1               False           0           0             0     False
# 2               False           0           0             0     False
# 3               False           0           0             0     False
# 4               False           0           0             0     False
# 5               False           0           0             0     False
# 6               False           0           0             0     False
# 7               False           0           0             0     False
# 8               False           0           0             0     False
# 9               False           0           0             0     False
# 10              False           0           0             0     False
# 11              False           0           0             0     False
# 12              False           0           0             0     False
# 13              False           0           0             0     False
# 14              False           0           0             0     False
# 15              False           0           0             0     False
# 16              False           0           0             0     False
# 17              False           0           0             0     False
# 18              False           0           0             0     False
# 19              False           0           0             0     False
# 20              False           0           0             0     False
# 21              False           0           0             0     False
# 22              False           0           0             0     False
# 23              False           0           0             0     False
# 24              False           0           0             0     False
# 25              False           0           0             0     False
# 26              False           0           0             0     False
#
#                                                source  \
# 0   <a href="http://everyearthquake.com" rel="nofo...
# 1   <a href="http://everyearthquake.com" rel="nofo...
# 2   <a href="http://everyearthquake.com" rel="nofo...
# 3   <a href="http://everyearthquake.com" rel="nofo...
# 4   <a href="http://everyearthquake.com" rel="nofo...
# 5   <a href="http://everyearthquake.com" rel="nofo...
# 6   <a href="http://everyearthquake.com" rel="nofo...
# 7   <a href="http://everyearthquake.com" rel="nofo...
# 8   <a href="http://everyearthquake.com" rel="nofo...
# 9   <a href="http://everyearthquake.com" rel="nofo...
# 10  <a href="http://everyearthquake.com" rel="nofo...
# 11  <a href="http://everyearthquake.com" rel="nofo...
# 12  <a href="http://everyearthquake.com" rel="nofo...
# 13  <a href="http://everyearthquake.com" rel="nofo...
# 14  <a href="http://everyearthquake.com" rel="nofo...
# 15  <a href="http://everyearthquake.com" rel="nofo...
# 16  <a href="http://everyearthquake.com" rel="nofo...
# 17  <a href="http://everyearthquake.com" rel="nofo...
# 18  <a href="http://everyearthquake.com" rel="nofo...
# 19  <a href="http://everyearthquake.com" rel="nofo...
# 20  <a href="http://everyearthquake.com" rel="nofo...
# 21  <a href="http://everyearthquake.com" rel="nofo...
# 22  <a href="http://everyearthquake.com" rel="nofo...
# 23  <a href="http://everyearthquake.com" rel="nofo...
# 24  <a href="http://everyearthquake.com" rel="nofo...
# 25  <a href="http://everyearthquake.com" rel="nofo...
# 26  <a href="http://everyearthquake.com" rel="nofo...
#
#                                                  text   timestamp_ms  \
# 0   USGS reports a M1.29 #earthquake 4km W of Mamm...  1517184003801
# 1   USGS reports a M0.56 #earthquake 8km N of Anza...  1515480242786
# 2   USGS reports a M0.51 #earthquake 14km W of Anz...  1515399842598
# 3   USGS reports a M0.52 #earthquake 7km NW of The...  1517774341896
# 4   USGS reports a M1 #earthquake 7km NW of The Ge...  1517348222401
# 5   USGS reports a M0.47 #earthquake 2km NNW of Th...  1515652322412
# 6   USGS reports a M2.13 #earthquake Greater Los A...  1516875721872
# 7   USGS reports a M0.56 #earthquake 7km NW of The...  1518128402871
# 8   USGS reports a M1.1 #earthquake 11km NE of Coa...  1518028143298
# 9   USGS reports a M1 #earthquake 8km ENE of Mammo...  1515385142328
# 10  USGS reports a M1.06 #earthquake 8km NE of Agu...  1517784601843
# 11  USGS reports a M0.68 #earthquake 10km ENE of M...  1515641582281
# 12  USGS reports a M1 #earthquake 7km NW of The Ge...  1516459081748
# 13  USGS reports a M1.04 #earthquake 6km NW of The...  1518015122798
# 14  USGS reports a M3.07 #earthquake 43km NW of St...  1517344202425
# 15  USGS reports a M0.78 #earthquake 5km WNW of Th...  1517321162474
# 16  USGS reports a M0.81 #earthquake 15km SSW of L...  1517888342412
# 17  USGS reports a M1.09 #earthquake 9km ENE of Ma...  1517536682156
# 18  USGS reports a M0.9 #earthquake 1km ESE of The...  1516013882681
# 19  USGS reports a M0.96 #earthquake 14km W of Tom...  1516695363948
# 20  USGS reports a M0.56 #earthquake 2km NNW of Th...  1517482742044
# 21  USGS reports a M #earthquake 11km S of Tres Pi...  1515796382741
# 22  USGS reports a M1.27 #earthquake 42km NW of Se...  1516459921630
# 23  USGS reports a M0.96 #earthquake 2km ENE of Th...  1515385202610
# 24  USGS reports a M1.66 #earthquake 8km SW of Hol...  1517838541664
# 25  USGS reports a M1.01 #earthquake 12km W of Agu...  1517343302256
# 26  USGS reports a M1.08 #earthquake 22km ENE of W...  1517697541877
#
#    truncated                                               user
# 0      False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 1      False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 2      False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 3      False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 4      False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 5      False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 6      False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 7      False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 8      False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 9      False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 10     False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 11     False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 12     False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 13     False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 14     False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 15     False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 16     False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 17     False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 18     False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 19     False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 20     False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 21     False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 22     False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 23     False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 24     False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 25     False  {'id': 1414684496, 'id_str': '1414684496', 'na...
# 26     False  {'id': 1414684496, 'id_str': '1414684496', 'na...
#
# [27 rows x 29 columns]

# %%
pd.DataFrame(tw).text
# Out:
# 0     USGS reports a M1.29 #earthquake 4km W of Mamm...
# 1     USGS reports a M0.56 #earthquake 8km N of Anza...
# 2     USGS reports a M0.51 #earthquake 14km W of Anz...
# 3     USGS reports a M0.52 #earthquake 7km NW of The...
# 4     USGS reports a M1 #earthquake 7km NW of The Ge...
# 5     USGS reports a M0.47 #earthquake 2km NNW of Th...
# 6     USGS reports a M2.13 #earthquake Greater Los A...
# 7     USGS reports a M0.56 #earthquake 7km NW of The...
# 8     USGS reports a M1.1 #earthquake 11km NE of Coa...
# 9     USGS reports a M1 #earthquake 8km ENE of Mammo...
# 10    USGS reports a M1.06 #earthquake 8km NE of Agu...
# 11    USGS reports a M0.68 #earthquake 10km ENE of M...
# 12    USGS reports a M1 #earthquake 7km NW of The Ge...
# 13    USGS reports a M1.04 #earthquake 6km NW of The...
# 14    USGS reports a M3.07 #earthquake 43km NW of St...
# 15    USGS reports a M0.78 #earthquake 5km WNW of Th...
# 16    USGS reports a M0.81 #earthquake 15km SSW of L...
# 17    USGS reports a M1.09 #earthquake 9km ENE of Ma...
# 18    USGS reports a M0.9 #earthquake 1km ESE of The...
# 19    USGS reports a M0.96 #earthquake 14km W of Tom...
# 20    USGS reports a M0.56 #earthquake 2km NNW of Th...
# 21    USGS reports a M #earthquake 11km S of Tres Pi...
# 22    USGS reports a M1.27 #earthquake 42km NW of Se...
# 23    USGS reports a M0.96 #earthquake 2km ENE of Th...
# 24    USGS reports a M1.66 #earthquake 8km SW of Hol...
# 25    USGS reports a M1.01 #earthquake 12km W of Agu...
# 26    USGS reports a M1.08 #earthquake 22km ENE of W...
# Name: text, dtype: object
