# %% [markdown]
# # Sharing Processes with a Team

# %% [markdown]
# ## Connection and Cursor
#
# We will use a connection object to define our connection to our database over a network.
#
# We will use a cursor object to write to the database. The cursor is created by a class function of the connection object.

# %%
import psycopg2 as pg2
from psycopg2.extras import RealDictCursor

connection = pg2.connect(host='this_postgis',
                         user='postgres',
                         database='postgres')
cursor = connection.cursor(cursor_factory=RealDictCursor)

# %% [markdown]
# The cursor can be used to execute queries and then to fetch the results of the query.

# %%
result = cursor.execute("SELECT * FROM business LIMIT 2;")

# %%
results = cursor.fetchall()
results
# Out:
# [{'id': 10,
#   'name': 'TIRAMISU KITCHEN',
#   'address': '033 BELDEN PL',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'postal_code': 94104,
#   'latitude': 37.791116,
#   'longitude': -122.403816,
#   'phone_number': '+14154217044'},
#  {'id': 19,
#   'name': 'NRGIZE LIFESTYLE CAFE',
#   'address': '1200 VAN NESS AVE, 3RD FLOOR',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'postal_code': 94109,
#   'latitude': 37.786848,
#   'longitude': -122.421547,
#   'phone_number': '+14157763262'}]

# %%
import pandas as pd
pd.DataFrame(results)
# Out:
#                         address           city  id   latitude   longitude  \
# 0                 033 BELDEN PL  San Francisco  10  37.791116 -122.403816
# 1  1200 VAN NESS AVE, 3RD FLOOR  San Francisco  19  37.786848 -122.421547
#
#                     name  phone_number  postal_code state
# 0       TIRAMISU KITCHEN  +14154217044        94104    CA
# 1  NRGIZE LIFESTYLE CAFE  +14157763262        94109    CA

# %%
connection.close()

# %% [markdown]
# Because we used the `cursor_factory=RealDictCursor` argument, the results return a list of dictionary objects from the database.
#
# The advantage of this is that we can display these results easily with a DataFrame.

# %%
import pandas as pd

# %%
connection = pg2.connect(host='this_postgis',
                         user='postgres',
                         database='postgres')
cursor = connection.cursor(cursor_factory=RealDictCursor)
result = cursor.execute("SELECT * FROM business LIMIT 2;")
pd.DataFrame(cursor.fetchall())
# Out:
#                         address           city  id   latitude   longitude  \
# 0                 033 BELDEN PL  San Francisco  10  37.791116 -122.403816
# 1  1200 VAN NESS AVE, 3RD FLOOR  San Francisco  19  37.786848 -122.421547
#
#                     name  phone_number  postal_code state
# 0       TIRAMISU KITCHEN  +14154217044        94104    CA
# 1  NRGIZE LIFESTYLE CAFE  +14157763262        94109    CA

# %%
connection.close()

# %% [markdown]
# ## `lib.db_helper`

# %% [markdown]
# Because we will keep using the connection-cursor pattern, we have written it into a sub-module.

# %%
cd /home/jovyan
# Out:
# /home/jovyan

# %%
import lib.db_helper as db

# %% [markdown]
# #### `db.connect_to_db()`
#
# Contains our connection credentials and returns a connection and cursor.
#
#     def connect_to_db():
#         con = pg2.connect(host='postgis',
#                           dbname='postgres',
#                           user='postgres')
#         cur = con.cursor(cursor_factory=RealDictCursor)
#         return con, cur

# %%
connection, cursor = db.connect_to_db()
result = cursor.execute("SELECT * FROM business LIMIT 2;")
pd.DataFrame(cursor.fetchall())
# Out:
#                         address           city  id   latitude   longitude  \
# 0                 033 BELDEN PL  San Francisco  10  37.791116 -122.403816
# 1  1200 VAN NESS AVE, 3RD FLOOR  San Francisco  19  37.786848 -122.421547
#
#                     name  phone_number  postal_code state
# 0       TIRAMISU KITCHEN  +14154217044        94104    CA
# 1  NRGIZE LIFESTYLE CAFE  +14157763262        94109    CA

# %%
connection.close()

# %% [markdown]
# #### `db.query_to_dictionary()`
#
# 1. creates a connection and a cursor
# 1. uses the cursor to execute a query
# 1. if `fetch_res` is `True` it fetches the results, otherwise results are `None`
# 1. closes the connection and returns `results`
#
#
#     def query_to_dictionary(query, fetch_res=True):
#         con, cur = connect_to_db()
#         cur.execute(query)
#         if fetch_res:
#             results = cur.fetchall()
#         else:
#             results = None
#         con.close()
#         return results

# %%
db.query_to_dictionary("""SELECT * FROM business LIMIT 2;""")
# Out:
# [{'id': 10,
#   'name': 'TIRAMISU KITCHEN',
#   'address': '033 BELDEN PL',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'postal_code': 94104,
#   'latitude': 37.791116,
#   'longitude': -122.403816,
#   'phone_number': '+14154217044'},
#  {'id': 19,
#   'name': 'NRGIZE LIFESTYLE CAFE',
#   'address': '1200 VAN NESS AVE, 3RD FLOOR',
#   'city': 'San Francisco',
#   'state': 'CA',
#   'postal_code': 94109,
#   'latitude': 37.786848,
#   'longitude': -122.421547,
#   'phone_number': '+14157763262'}]

# %%
db.query_to_dictionary("""SELECT * FROM business LIMIT 2;""", fetch_res=False)

# %% [markdown]
# #### `db.query_to_dataframe()`
#
# Wraps `query_to_dictionary()` in a `pandas.DataFrame`.
#
#     def query_to_dataframe(query):
#         return DataFrame(query_to_dictionary(query))

# %%
db.query_to_dataframe('SELECT * FROM business LIMIT 2;')
# Out:
#                         address           city  id   latitude   longitude  \
# 0                 033 BELDEN PL  San Francisco  10  37.791116 -122.403816
# 1  1200 VAN NESS AVE, 3RD FLOOR  San Francisco  19  37.786848 -122.421547
#
#                     name  phone_number  postal_code state
# 0       TIRAMISU KITCHEN  +14154217044        94104    CA
# 1  NRGIZE LIFESTYLE CAFE  +14157763262        94109    CA

# %% [markdown]
# ### Create new column in `business` table
#
# To demonstrate how transactions work, we will write a SQL query to create a new column in our database.

# %% [markdown]
# #### Run this if the column has already been created and you wish to run all cells in the notebook

# %%
# db.query_to_dictionary("""
# BEGIN;
# ALTER TABLE business DROP COLUMN gpnt_location;
# COMMIT;
# """, fetch_res=False)

# %%
db.query_to_dictionary("""
BEGIN;
ALTER TABLE business ADD COLUMN gpnt_location geometry(POINT,4326);
COMMIT;
""", fetch_res=False)

# %%
db.query_to_dataframe('SELECT * FROM business LIMIT 2;')
# Out:
#                         address           city gpnt_location  id   latitude  \
# 0                 033 BELDEN PL  San Francisco          None  10  37.791116
# 1  1200 VAN NESS AVE, 3RD FLOOR  San Francisco          None  19  37.786848
#
#     longitude                   name  phone_number  postal_code state
# 0 -122.403816       TIRAMISU KITCHEN  +14154217044        94104    CA
# 1 -122.421547  NRGIZE LIFESTYLE CAFE  +14157763262        94109    CA

# %%
db.query_to_dataframe('SELECT * FROM business;')
# Out:
#                                 address           city gpnt_location     id  \
# 0                         033 BELDEN PL  San Francisco          None     10
# 1          1200 VAN NESS AVE, 3RD FLOOR  San Francisco          None     19
# 2         500 CALIFORNIA ST, 2ND  FLOOR  San Francisco          None     24
# 3                  2801 LEAVENWORTH ST   San Francisco          None     31
# 4                       3202 FOLSOM ST   San Francisco          None     45
# 5                        747 IRVING ST   San Francisco          None     48
# 6                     1815  MARKET ST.   San Francisco          None     50
# 7                         2180 POST ST   San Francisco          None     54
# 8                       1799 CHURCH ST   San Francisco          None     56
# 9                          91 DRUMM ST   San Francisco          None     58
# 10                    PIER 39  SPACE A3  San Francisco          None     61
# 11                      1800 IRVING ST   San Francisco          None     66
# 12                        3248 22ND ST   San Francisco          None     67
# 13                       1700 POST ST K  San Francisco          None     71
# 14                    2101 FILLMORE ST   San Francisco          None     73
# 15         500 CALIFORNIA ST, 3RD FLOOR  San Francisco          None     76
# 16          500 CALIFORNIA ST, BASEMENT  San Francisco          None     77
# 17                      2199 FULTON ST   San Francisco          None     80
# 18                        2350 TURK ST   San Francisco          None     81
# 19                        1435 17TH ST   San Francisco          None     88
# 20                    419 CORTLAND AVE   San Francisco          None     95
# 21                    754 COLUMBUS AVE   San Francisco          None     98
# 22                         779 CLAY ST   San Francisco          None     99
# 23                      1099 POWELL ST   San Francisco          None    101
# 24                       542A MASON ST   San Francisco          None    102
# 25                          900 PINE ST  San Francisco          None    108
# 26                   PIER 7 EMBARCADERO  San Francisco          None    116
# 27                         431 BUSH ST   San Francisco          None    121
# 28                     391 BROADWAY ST   San Francisco          None    125
# 29                     684 BROADWAY ST   San Francisco          None    126
# ...                                 ...            ...           ...    ...
# 6131                     400 HAIGHT ST   San Francisco          None  86972
# 6132                     429 CASTRO ST   San Francisco          None  86986
# 6133                    1500 MARKET ST   San Francisco          None  86990
# 6134                       500 POST ST   San Francisco          None  86991
# 6135                      500 POST ST    San Francisco          None  86992
# 6136                       500 POST ST   San Francisco          None  86994
# 6137                       500 POST ST   San Francisco          None  86995
# 6138                       500 POST ST   San Francisco          None  86997
# 6139               280 GOLDEN GATE AVE   San Francisco          None  87015
# 6140                     OFF THE GRID    San Francisco          None  87021
# 6141                    2809 TAYLOR ST   San Francisco          None  87044
# 6142                     50 FREMONT ST   San Francisco          None  87046
# 6143                     900 SUTTER ST   San Francisco          None  87048
# 6144                     433 KEARNY ST   San Francisco          None  87051
# 6145       101 MONTGOMERY ST SUITE 101C  San Francisco          None  87059
# 6146                   5241 GEARY BLVD   San Francisco          None  87107
# 6147                       809 BUSH ST   San Francisco          None  87121
# 6148                   3876 NORIEGA ST   San Francisco          None  87122
# 6149                      842 GEARY ST   San Francisco          None  87123
# 6150         PIER 15, THE EMBARCADERO    San Francisco          None  87149
# 6151         PIER 15, THE EMBARCADERO    San Francisco          None  87154
# 6152                      4401 18TH ST   San Francisco          None  87165
# 6153       599 SKYLINE BLVD #1 LAKESIDE  San Francisco          None  87200
# 6154                 646 WASHINGTON ST   San Francisco          None  87201
# 6155  599 SKYLINE BLVD #2 DRIVING RANGE  San Francisco          None  87202
# 6156                  1740 FILLMORE ST   San Francisco          None  87213
# 6157            505 SAMSOME ST STE. 101  San Francisco          None  87271
# 6158                3251 20TH AVE 250-J  San Francisco          None  87277
# 6159                       127 EDDY ST   San Francisco          None  87282
# 6160                      4230 18TH ST   San Francisco          None  87316
#
#        latitude   longitude                                  name  \
# 0     37.791116 -122.403816                      TIRAMISU KITCHEN
# 1     37.786848 -122.421547                 NRGIZE LIFESTYLE CAFE
# 2     37.792888 -122.403135    OMNI S.F. HOTEL - 2ND FLOOR PANTRY
# 3     37.807155 -122.419004        NORMAN'S ICE CREAM AND FREEZES
# 4     37.747114 -122.413641                   CHARLIE'S DELI CAFE
# 5     37.764013 -122.465749                            ART'S CAFE
# 6     37.771437 -122.423892                            SUSHI ZONE
# 7     37.784626 -122.437734                   RHODA GOLDMAN PLAZA
# 8     37.742325 -122.426476                            CAFE X + O
# 9     37.794483 -122.396584                           OASIS GRILL
# 10    37.808240 -122.410189                              CHOWDERS
# 11    37.763578 -122.477461                      STARBUCKS COFFEE
# 12    37.755419 -122.419542                       REVOLUTION CAFE
# 13    37.785567 -122.430074                      KAPPA RESTAURANT
# 14    37.788932 -122.433895                     DINO'S UNCLE VITO
# 15    37.792888 -122.403135    OMNI S.F. HOTEL - 3RD FLOOR PANTRY
# 16    37.792888 -122.403135  OMNI S.F. HOTEL - EMPLOYEE CAFETERIA
# 17    37.774941 -122.452797                       LAW SCHOOL CAFE
# 18    37.778468 -122.448484                   CLUB ED/BON APPETIT
# 19    37.765003 -122.398084                          J.B.'S PLACE
# 20    37.739207 -122.417447                                  VEGA
# 21    37.801665 -122.412104                          XOX TRUFFLES
# 22    37.794293 -122.405967         J & M A-1 CAFE RESTAURANT LLC
# 23    37.794615 -122.409705                      CABLE CAR CORNER
# 24    37.788484 -122.410045                     AKIKO'S SUSHI BAR
# 25    37.790868 -122.410854                             RUE LEPIC
# 26    37.793874 -122.396464             THE WATERFRONT RESTAURANT
# 27    37.790643 -122.404676                          AKIKOS SUSHI
# 28    37.798233 -122.403637                           CENTERFOLDS
# 29    37.797708 -122.408413                      BROADWAY DIM SUM
# ...         ...         ...                                   ...
# 6131        NaN         NaN                   THE LODGE ON HAIGHT
# 6132        NaN         NaN                        CASTRO THEATRE
# 6133        NaN         NaN                     ALLSTARS CAFE INC
# 6134        NaN         NaN           JW MARRIOTT SF UNION SQUARE
# 6135        NaN         NaN           JW MARRIOTT SF UNION SQUARE
# 6136        NaN         NaN           JW MARRIOTT SF UNION SQUARE
# 6137        NaN         NaN           JW MARRIOTT SF UNION SQUARE
# 6138        NaN         NaN           JW MARRIOTT SF UNION SQUARE
# 6139        NaN         NaN                  MORTY'S DELICATESSEN
# 6140        NaN         NaN              SOUTHERN COMFORT KITCHEN
# 6141        NaN         NaN             SABELLA & LATORRE SEAFOOD
# 6142        NaN         NaN                          PRETTY SWEET
# 6143        NaN         NaN                      HANS COFFEE SHOP
# 6144        NaN         NaN                     COFFEE BAR KEARNY
# 6145        NaN         NaN                 COFFEE BAR MONTGOMERY
# 6146        NaN         NaN        RUSSIAN RENAISSANCE RESTAURANT
# 6147        NaN         NaN                         JASMIN'S CAFE
# 6148        NaN         NaN                     DEVIL'S TEETH INC
# 6149        NaN         NaN                           MONGOL CAFE
# 6150        NaN         NaN                         SEISMIC JOINT
# 6151        NaN         NaN                   SEAGLASS RESTAURANT
# 6152        NaN         NaN                           THE RAINBOW
# 6153        NaN         NaN                         HOT DOG BILLS
# 6154        NaN         NaN             OOLONG NOODLES RESTAURANT
# 6155        NaN         NaN                         HOT DOG BILLS
# 6156        NaN         NaN               INDIA PALACE RESTAURANT
# 6157        NaN         NaN                            ILLY CAFFE
# 6158        NaN         NaN                    HOT DOG ON A STICK
# 6159        NaN         NaN                NEW YORK PIZZA KITCHEN
# 6160        NaN         NaN                     BIT ME SANDWICHES
#
#       phone_number  postal_code state
# 0     +14154217044      94104.0    CA
# 1     +14157763262      94109.0    CA
# 2     +14156779494      94104.0    CA
# 3                       94133.0    CA
# 4     +14156415051      94110.0    CA
# 5     +14156657440      94122.0    CA
# 6     +14156211114      94103.0    CA
# 7     +14153455060      94115.0    CA
# 8     +14158263535      94131.0    CA
# 9     +14158341942      94111.0    CA
# 10    +14153914737      94133.0    CA
# 11    +14152427970      94122.0    CA
# 12    +14156420474      94110.0    CA
# 13    +14156736004      94115.0    CA
# 14    +14159224700      94115.0    CA
# 15    +14156779494      94104.0    CA
# 16    +14156779494      94104.0    CA
# 17    +14154222268      94117.0    CA
# 18    +14154225849      94117.0    CA
# 19    +14155848446      94107.0    CA
# 20    +14152856000      94110.0    CA
# 21    +14154214814      94133.0    CA
# 22    +14156057219      94108.0    CA
# 23    +14153625925      94108.0    CA
# 24    +14159898218      94102.0    CA
# 25    +14154746070      94108.0    CA
# 26    +14153912696      94111.0    CA
# 27    +14153973218      94108.0    CA
# 28    +14158340662      94133.0    CA
# 29    +14159892038      94133.0    CA
# ...            ...          ...   ...
# 6131  +14158729582      94117.0    CA
# 6132  +14156216350      94114.0    CA
# 6133  +14152529888      94102.0    CA
# 6134  +14159292030      94102.0    CA
# 6135  +14159292030      94102.0    CA
# 6136  +14159292030      94102.0    CA
# 6137  +14159292030          NaN    CA
# 6138  +14159292030      94102.0    CA
# 6139  +14155673354      94102.0    CA
# 6140  +14155496155          NaN    CA
# 6141  +14156732824      94133.0    CA
# 6142  +14153292125      94105.0    CA
# 6143  +14157767875      94109.0    CA
# 6144  +14158158774      94108.0    CA
# 6145  +14158158774      94014.0    CA
# 6146  +14157528558      94118.0    CA
# 6147                    94108.0    CA
# 6148  +14156835533      94122.0    CA
# 6149  +14159138879          NaN    CA
# 6150                    94111.0    CA
# 6151  +14155284783      94111.0    CA
# 6152  +14158292018      94114.0    CA
# 6153  +14158734301      94132.0    CA
# 6154  +14153889673      94111.0    CA
# 6155  +14158734301      94132.0    CA
# 6156  +14155677789      94115.0    CA
# 6157                    94111.0    CA
# 6158  +14155144500      94132.0    CA
# 6159  +14154091212      94102.0    CA
# 6160                    94114.0    CA
#
# [6161 rows x 10 columns]

# %% [markdown]
# # Clean the Data

# %%
select_count_business = """
SELECT COUNT(*) FROM business
"""
db.query_to_dataframe(select_count_business)
# Out:
#    count
# 0   6161

# %%
select_count_by_postal_code = """
SELECT postal_code, COUNT(*) FROM business
GROUP BY postal_code
ORDER BY postal_code
"""
db.query_to_dataframe(select_count_by_postal_code)
# Out:
#     count  postal_code
# 0       1          0.0
# 1       1      84105.0
# 2       1      92672.0
# 3       2      94013.0
# 4       3      94014.0
# 5       1      94066.0
# 6       3      94101.0
# 7     447      94102.0
# 8     552      94103.0
# 9     132      94104.0
# 10    225      94105.0
# 11    429      94107.0
# 12    223      94108.0
# 13    373      94109.0
# 14    559      94110.0
# 15    280      94111.0
# 16    187      94112.0
# 17    219      94114.0
# 18    233      94115.0
# 19     94      94116.0
# 20    194      94117.0
# 21    244      94118.0
# 22      1      94120.0
# 23    161      94121.0
# 24    258      94122.0
# 25    173      94123.0
# 26    153      94124.0
# 27     67      94127.0
# 28      2      94129.0
# 29      8      94130.0
# 30     45      94131.0
# 31    126      94132.0
# 32    425      94133.0
# 33     71      94134.0
# 34      1      94140.0
# 35      5      94143.0
# 36     11      94158.0
# 37      1      94188.0
# 38      1      94513.0
# 39      1      94545.0
# 40      1      94602.0
# 41      1      94609.0
# 42      1      94621.0
# 43      1      95105.0
# 44      1  941033148.0
# 45    243          NaN

# %% [markdown]
# Note that we might also have invalid data.

# %%
select_count_business_invalid_data = """
SELECT COUNT(*) FROM business
WHERE latitude = 0 AND longitude = 0;"""

# %%
db.query_to_dataframe(select_count_business_invalid_data)
# Out:
#    count
# 0     14

# %%
select_count_business_valid = """
SELECT COUNT(*) FROM business
WHERE 
    (latitude IS NOT NULL
     AND longitude IS NOT NULL)
AND 
    (latitude != 0 
     AND longitude != 0)
"""

select_count_business_invalid = """
SELECT COUNT(*) FROM business
WHERE 
    (latitude IS NULL
     OR longitude IS NULL)
OR 
    (latitude = 0 
     OR longitude = 0)
"""

# %%
db.query_to_dataframe(select_count_business_valid)
# Out:
#    count
# 0   3735

# %%
db.query_to_dataframe(select_count_business_invalid)
# Out:
#    count
# 0   2426

# %% [markdown]
# ### Store Valid and Invalid Queries

# %% [markdown]
# We will also make use of subqueries. We will define two:
#
# 1. a subquery for all businesses with valid lat/long
# 1. a subquery for all businesses with invalid lat/long

# %% [markdown]
# #### Valid Business Query

# %%
select_business_valid = """
SELECT * FROM business
WHERE 
    (latitude IS NOT NULL
     AND longitude IS NOT NULL)
AND 
    (latitude != 0 
     AND longitude != 0)
"""

select_business_invalid = """
SELECT * FROM business
WHERE 
    (latitude IS NULL
     AND longitude IS NULL)
OR 
    (latitude = 0 
     AND longitude = 0)
"""

# %%
print(db.query_to_dataframe(select_business_valid).shape)
db.query_to_dataframe(select_business_valid).sample(4)
# Out:
# (3735, 10)
#                    address           city gpnt_location     id   latitude  \
# 1975      4661 MISSION ST   San Francisco          None  18310  37.723782
# 1121       2 FOLSOM STREET  San Francisco          None   3960  37.790793
# 1736         698 HAYES ST   San Francisco          None   7653  37.776298
# 147   2 NEW MONTGOMERY ST   San Francisco          None    519  37.788286
#
#        longitude                               name  phone_number  \
# 1975 -122.435446                         CHEF HUNAN  +14153335588
# 1121 -122.390218                           GAP INC.  +14154272750
# 1736 -122.427744                       HAYES MARKET  +14158615267
# 147  -122.401543  SHERATON PALACE - EMP.  CAFETERIA  +14155121111
#
#       postal_code state
# 1975      94112.0    CA
# 1121      94105.0    CA
# 1736      94102.0    CA
# 147       94105.0    CA

# %%
print(db.query_to_dataframe(select_business_invalid).shape)
db.query_to_dataframe(select_business_invalid).sample(4)
# Out:
# (2426, 10)
#                 address           city gpnt_location     id  latitude  \
# 1617       36 05TH ST    San Francisco          None  81508       NaN
# 650     501 DOLORES ST   San Francisco          None  74999       NaN
# 11            PIER 45    San Francisco          None   5281       NaN
# 215   814-816 IRVING ST  San Francisco          None  68148       NaN
#
#       longitude                     name  phone_number  postal_code state
# 1617        NaN                MO'Z CAFE  +14157771080          NaN    CA
# 650         NaN        DOLORES PARK CAFE  +14156212936      94110.0    CA
# 11          NaN           EVA'S CATERING  +14158281026      94122.0    CA
# 215         NaN  SHENG KEE BAKERY & CAFE  +14154683800      94122.0    CA

# %% [markdown]
# ### Explore Postal Code and Lat/Long

# %% [markdown]
# First, let's get the postal codes with a count of less than 10. We will use a sub-query.
#
# Let's use these subqueries to help us to clean the data.

# %% [markdown]
# Note that we re-use `select_count_by_postal_code`.

# %%
print(select_count_by_postal_code)
# Out:
# SELECT postal_code, COUNT(*) FROM business
# GROUP BY postal_code
# ORDER BY postal_code

# %%
select_postal_code_by_postal_code_less_than_10 = """
SELECT postal_code FROM 
    ({}) q
WHERE count < 10
""".format(select_count_by_postal_code)

print(select_postal_code_by_postal_code_less_than_10)
# Out:
# SELECT postal_code FROM
#     (
# SELECT postal_code, COUNT(*) FROM business
# GROUP BY postal_code
# ORDER BY postal_code
# ) q
# WHERE count < 10

# %% [markdown]
# Note that we are using a subquery here.
#
# e.g.
#
#     SELECT * FROM (SUBQUERY) sub_query_name;

# %%
db.query_to_dataframe(select_postal_code_by_postal_code_less_than_10)
# Out:
#    postal_code
# 0            0
# 1        94013
# 2        94101
# 3        94120
# 4        94130
# 5        94140
# 6        94143
# 7        94513
# 8        94609
# 9        95105

# %% [markdown]
# We'll think of these as our "bad postal codes". We can think of the query we defined as a list of these codes. That query was

# %%
print(select_postal_code_by_postal_code_less_than_10)
# Out:
# SELECT postal_code FROM
#     (
# SELECT postal_code, COUNT(*) FROM business
# GROUP BY postal_code
# ORDER BY postal_code
# ) q
# WHERE count < 10

# %% [markdown]
# Do we have (lat,long) pairs for these locations? Let's select all rows with one of these postal codes.

# %% [markdown]
# ### `IN`

# %% [markdown]
# To do this we will use the SQL keyword `IN`. `IN` checks a column against a list of items.

# %% [markdown]
# e.g.
#
#     SELECT * FROM my_table WHERE my_column IN ('1,2,3,4,5');

# %% [markdown]
# # We will replace the list with our Sub-Query!!

# %%
select_business_where_bad_postal_code = """
SELECT * FROM business WHERE postal_code IN ({})""".format(select_postal_code_by_postal_code_less_than_10)
print(select_business_where_bad_postal_code)
# Out:
# SELECT * FROM business WHERE postal_code IN (
# SELECT postal_code FROM
#     (
# SELECT postal_code, COUNT(*) FROM business
# GROUP BY postal_code
# ORDER BY postal_code
# ) q
# WHERE count < 10
# )

# %%
db.query_to_dataframe(select_business_where_bad_postal_code).sample(5)
# Out:
#                                 address           city gpnt_location     id  \
# 31                   101 MONTGOMERY ST   San Francisco          None  83744
# 15                PUBLIC RIGHT OF WAY    San Francisco          None  65673
# 17                       OFF THE GRID    San Francisco          None  67875
# 28                         428 11TH ST   San Francisco          None  80829
# 9   60 CLIPPER COVE WAY TREASURE ISLAND  San Francisco          None  60349
#
#      latitude   longitude                         name  phone_number  \
# 31        NaN         NaN                LA FROMAGERIE  +14153682943
# 15  37.834628 -122.264171             DOC'S OF THE BAY  +14156883245
# 17  37.777122 -122.419639           THE CHAIRMAN TRUCK  +14158461711
# 28        NaN         NaN              KOREAN BOBCHA#2  +14157305897
# 9   37.816422 -122.370584  TREASURE ISLAND BAR & GRILL  +14156422431
#
#     postal_code state
# 31        94101    CA
# 15        94609    CA
# 17            0    CA
# 28        94014    CA
# 9         94130    CA

# %%
#db.query_to_dataframe(select_business_where_bad_postal_code)

# %% [markdown]
# Note that some of these have a lat and long.

# %% [markdown]
# What we want is rows that have "bad postal codes" and no (lat, long) pair.

# %% [markdown]
# ### A Nested Query
#
# To get these we will write a nested query that looks like this:
#
#     SELECT * FROM (invalid_lat_long) WHERE postal_code IN (bad_postal_code_str)

# %%
select_invalid_business_where_bad_postal_code = """
SELECT * 
FROM ({}) q
WHERE postal_code IN ({})
""".format(select_business_invalid, select_postal_code_by_postal_code_less_than_10)
print(select_invalid_business_where_bad_postal_code)
# Out:
# SELECT *
# FROM (
# SELECT * FROM business
# WHERE
#     (latitude IS NULL
#      AND longitude IS NULL)
# OR
#     (latitude = 0
#      AND longitude = 0)
# ) q
# WHERE postal_code IN (
# SELECT postal_code FROM
#     (
# SELECT postal_code, COUNT(*) FROM business
# GROUP BY postal_code
# ORDER BY postal_code
# ) q
# WHERE count < 10
# )

# %%
db.query_to_dataframe(select_invalid_business_where_bad_postal_code)
# Out:
#                                               address           city  \
# 0                             VARIOUS LOACATIONS (17)  San Francisco
# 1                                   VARIOUS LOCATIONS  San Francisco
# 2                                  390 CLEMENTINA ST   San Francisco
# 3                       TREASURE ISLAND  888 AVENUE H  San Francisco
# 4             150 04TH ST.,  TREASURE ISLAND  SUITE 1  San Francisco
# 5                 HUNTER'S POINT SHIPYARD, BLDG.110    San Francisco
# 6                                      5383 CAPWELL    San Francisco
# 7                                 150 04TH ST SUITE 1  San Francisco
# 8                                  101 BAYSHORE BLVD   San Francisco
# 9                                    2769 LOMBARD ST   San Francisco
# 10  200 CALIFORNIA AVE., BLDG 180S, TREASURE ISLAND    San Francisco
# 11                                     OFF THE GRID    San Francisco
# 12                                       401 13TH ST   San Francisco
# 13                                 530 PARNASSUS AVE   San Francisco
# 14                                       428 11TH ST   San Francisco
# 15                                 500 PARNASSUS AVE   San Francisco
# 16             401 CALIFORNIA AVE., TREASURE ISLAND    San Francisco
# 17                                 101 MONTGOMERY ST   San Francisco
# 18                                   2937 MISSION ST   San Francisco
# 19                            215 FREMONT ST SUITE 2B  San Francisco
# 20                                    1900 MARKET ST   San Francisco
# 21                                       2 KORET WAY   San Francisco
# 22                       101 MONTGOMERY ST SUITE 101C  San Francisco
#
#    gpnt_location     id latitude longitude  \
# 0           None   5755     None      None
# 1           None   5757     None      None
# 2           None   6029     None      None
# 3           None  63091     None      None
# 4           None  69804     None      None
# 5           None  71471     None      None
# 6           None  72127     None      None
# 7           None  73799     None      None
# 8           None  74674     None      None
# 9           None  77759     None      None
# 10          None  78650     None      None
# 11          None  79607     None      None
# 12          None  79829     None      None
# 13          None  80554     None      None
# 14          None  80829     None      None
# 15          None  81134     None      None
# 16          None  81885     None      None
# 17          None  83744     None      None
# 18          None  83777     None      None
# 19          None  84698     None      None
# 20          None  85459     None      None
# 21          None  85506     None      None
# 22          None  87059     None      None
#
#                                    name  phone_number  postal_code state
# 0                         J & J VENDING  +14156750910        94545    CA
# 1                     RICO VENDING, INC  +14155836723        94066    CA
# 2   ALEXIS APARTMENTS SR. MEALS PROGRAM  +14154959541    941033148    CA
# 3                           MAYA WATERS  +14156137162        94130    CA
# 4                    ISLAND COVE MARKET  +14153912299        94130    CA
# 5                               O'CACAO  +14159062574        94188    CA
# 6                      REVOLUTION FOODS                      94621    CA
# 7                    ISLAND COVE MARKET  +14153912299        94130    CA
# 8                        ELI'S HOT DOGS  +14158301168        94014    CA
# 9                     PIZZERIA AVELLINO  +14157762500        94129    CA
# 10                  TREASURE BRANDS LLC  +14152919192        94130    CA
# 11               TAQUERIA ANGELICA'S #2  +14158343695        94129    CA
# 12                   ARACELY RESTAURANT  +14156940363        94130    CA
# 13                        CAFFE CENTRAL  +14159565101        94143    CA
# 14                      KOREAN BOBCHA#2  +14157305897        94014    CA
# 15                 CARMELINA'S TAQUERIA  +14155021121        94143    CA
# 16                      SF EVENT VENUES  +14157358423        94130    CA
# 17                        LA FROMAGERIE  +14153682943        94101    CA
# 18                            COCO FRIO  +14153751185        94101    CA
# 19                               FAYALA  +14154206274        84105    CA
# 20                           ORBIT ROOM  +14153705584        94602    CA
# 21                         LADLE & LEAF  +14158691585        94143    CA
# 22                COFFEE BAR MONTGOMERY  +14158158774        94014    CA

# %% [markdown]
# #### Let's use `DELETE` to get rid of rows that have no lat, long and a bad zip

# %% [markdown]
# First, let's collect a list of business `id`s.

# %%
select_invalid_business_id_where_bad_postal_code = """
SELECT id 
FROM ({}) q
WHERE postal_code IN ({})
""".format(select_business_invalid, select_postal_code_by_postal_code_less_than_10)
print(select_invalid_business_id_where_bad_postal_code)
# Out:
# SELECT id
# FROM (
# SELECT * FROM business
# WHERE
#     (latitude IS NULL
#      AND longitude IS NULL)
# OR
#     (latitude = 0
#      AND longitude = 0)
# ) q
# WHERE postal_code IN (
# SELECT postal_code FROM
#     (
# SELECT postal_code, COUNT(*) FROM business
# GROUP BY postal_code
# ORDER BY postal_code
# ) q
# WHERE count < 10
# )

# %%
db.query_to_dataframe(select_invalid_business_id_where_bad_postal_code)
# Out:
#        id
# 0    5755
# 1    5757
# 2    6029
# 3   63091
# 4   69804
# 5   71471
# 6   72127
# 7   73799
# 8   74674
# 9   77759
# 10  78650
# 11  79607
# 12  79829
# 13  80554
# 14  80829
# 15  81134
# 16  81885
# 17  83744
# 18  83777
# 19  84698
# 20  85459
# 21  85506
# 22  87059

# %%
print(select_invalid_business_id_where_bad_postal_code)
# Out:
# SELECT id
# FROM (
# SELECT * FROM business
# WHERE
#     (latitude IS NULL
#      AND longitude IS NULL)
# OR
#     (latitude = 0
#      AND longitude = 0)
# ) q
# WHERE postal_code IN (
# SELECT postal_code FROM
#     (
# SELECT postal_code, COUNT(*) FROM business
# GROUP BY postal_code
# ORDER BY postal_code
# ) q
# WHERE count < 10
# )

# %% [markdown]
# We can use this subquery in our `DELETE` query.

# %% [markdown]
# Remember, that a **delete** action is a write action and needs to be handled as a transaction. We need to `BEGIN` and `COMMIT`.

# %%
delete_invalid_business_bad_postal_code = """
BEGIN;
DELETE 
FROM business
WHERE id IN ({});
COMMIT;
""".format(select_invalid_business_id_where_bad_postal_code)
print(delete_invalid_business_bad_postal_code)
# Out:
# BEGIN;
# DELETE
# FROM business
# WHERE id IN (
# SELECT id
# FROM (
# SELECT * FROM business
# WHERE
#     (latitude IS NULL
#      AND longitude IS NULL)
# OR
#     (latitude = 0
#      AND longitude = 0)
# ) q
# WHERE postal_code IN (
# SELECT postal_code FROM
#     (
# SELECT postal_code, COUNT(*) FROM business
# GROUP BY postal_code
# ORDER BY postal_code
# ) q
# WHERE count < 10
# )
# );
# COMMIT;

# %% [markdown]
# Remember, when we execute this we do not need to fetch results so we should set `fetch_res` to `False`.

# %%
db.query_to_dictionary(delete_invalid_business_bad_postal_code, fetch_res=False) #doesn't work
# Out:
# ---------------------------------------------------------------------------
# IntegrityError                            Traceback (most recent call last)
# <ipython-input-57-ed58d789e217> in <module>()
# ----> 1 db.query_to_dictionary(delete_invalid_business_bad_postal_code, fetch_res=False)
#
# ~/lib/db_helper.py in query_to_dictionary(query, fetch_res)
#      12 def query_to_dictionary(query, fetch_res=True):
#      13     con, cur = connect_to_db()
# ---> 14     cur.execute(query)
#      15     if fetch_res:
#      16         results = cur.fetchall()
#
# /opt/conda/lib/python3.6/site-packages/psycopg2/extras.py in execute(self, query, vars)
#     247         self.column_mapping = []
#     248         self._query_executed = 1
# --> 249         return super(RealDictCursor, self).execute(query, vars)
#     250
#     251     def callproc(self, procname, vars=None):
#
# IntegrityError: update or delete on table "business" violates foreign key constraint "fk_business_id" on table "inspection"
# DETAIL:  Key (id)=(5755) is still referenced from table "inspection".

# %% [markdown]
# Let's have a look at the sql file used to define our database.

# %% [markdown]
# ```SQL
# CREATE TABLE business (
#     id INTEGER,
#     name TEXT,
#     address TEXT,
#     city TEXT,
#     state TEXT,
#     postal_code INTEGER,
#     latitude FLOAT,
#     longitude FLOAT,
#     phone_number TEXT,
#     PRIMARY KEY (id));
#
# CREATE TABLE inspection (
#     business_id INTEGER,
#     score INTEGER,
#     date TIMESTAMP,
#     type TEXT,
#     CONSTRAINT fk_business_id
#     FOREIGN KEY (business_id)
#     REFERENCES business (id));
#
# CREATE TABLE legend (
#     minimum_score INTEGER,
#     maximum_score INTEGER,
#     description TEXT);
#
# CREATE TABLE violation (
#     business_id INTEGER,
#     date TIMESTAMP,
#     description TEXT,
#     CONSTRAINT fk_business_id
#     FOREIGN KEY (business_id)
#     REFERENCES business (id));
#
# ```

# %% [markdown]
# Note that we have foreign key `CONSTRAINT`s on the `inspection` and `violation` tables.

# %% [markdown]
# This means that, in order to drop the businesses with "bad" data, we will need to drop any inspections and violations associated with these.

# %% [markdown]
# ### "Bad" Business Data

# %%
db.query_to_dataframe(select_invalid_business_id_where_bad_postal_code)
# Out:
#        id
# 0    5755
# 1    5757
# 2    6029
# 3   63091
# 4   69804
# 5   71471
# 6   72127
# 7   73799
# 8   74674
# 9   77759
# 10  78650
# 11  79607
# 12  79829
# 13  80554
# 14  80829
# 15  81134
# 16  81885
# 17  83744
# 18  83777
# 19  84698
# 20  85459
# 21  85506
# 22  87059

# %%
print(select_invalid_business_id_where_bad_postal_code)
# Out:
# SELECT id
# FROM (
# SELECT * FROM business
# WHERE
#     (latitude IS NULL
#      AND longitude IS NULL)
# OR
#     (latitude = 0
#      AND longitude = 0)
# ) q
# WHERE postal_code IN (
# SELECT postal_code FROM
#     (
# SELECT postal_code, COUNT(*) FROM business
# GROUP BY postal_code
# ORDER BY postal_code
# ) q
# WHERE count < 10
# )

# %%
select_violations_for_bad_biz = """
SELECT * FROM violation
WHERE business_id IN ({})
""".format(select_invalid_business_id_where_bad_postal_code)

# %%
db.query_to_dataframe(select_violations_for_bad_biz)
# Out:
#     business_id       date                                        description
# 0          6029 2014-03-13  Food safety certificate or food handler card n...
# 1          6029 2014-03-13  Unapproved or unmaintained equipment or utensi...
# 2         69804 2015-06-17                        Low risk vermin infestation
# 3         69804 2015-06-17            Moderate risk food holding temperature
# 4         69804 2013-09-26  No thermometers or uncalibrated thermometers  ...
# 5         69804 2013-09-26  Inadequate food safety knowledge or lack of ce...
# 6         71471 2013-05-02                              Improper food storage
# 7         74674 2015-08-18  Inadequate and inaccessible handwashing facili...
# 8         74674 2015-08-18  Permit license or inspection report not posted...
# 9         74674 2015-08-18  Mobile food facility with unapproved operating...
# 10        74674 2015-08-18  Inadequate sewage or wastewater disposal  [ da...
# 11        74674 2015-08-18  No hot water or running water  [ date violatio...
# 12        74674 2015-08-18  High risk food holding temperature   [ date vi...
# 13        74674 2015-08-18  Unclean hands or improper use of gloves  [ dat...
# 14        74674 2015-08-18  Food safety certificate or food handler card n...
# 15        74674 2014-06-23  No hot water or running water  [ date violatio...
# 16        74674 2014-06-23  Inadequate and inaccessible handwashing facili...
# 17        74674 2013-12-02  Inadequate and inaccessible handwashing facili...
# 18        74674 2013-12-02  Wiping cloths not clean or properly stored or ...
# 19        74674 2013-07-10  Inadequate and inaccessible handwashing facili...
# 20        74674 2013-07-10  Wiping cloths not clean or properly stored or ...
# 21        74674 2013-07-10  No hot water or running water  [ date violatio...
# 22        77759 2014-11-25  Permit license or inspection report not posted...
# 23        77759 2014-11-25  Unclean or degraded floors walls or ceilings  ...
# 24        77759 2014-11-25  High risk vermin infestation  [ date violation...
# 25        77759 2014-11-25  No thermometers or uncalibrated thermometers  ...
# 26        77759 2014-11-25  Inadequate warewashing facilities or equipment...
# 27        77759 2014-11-25  Food safety certificate or food handler card n...
# 28        79607 2015-04-08  Inadequately cleaned or sanitized food contact...
# 29        79607 2015-04-08                 Inadequate ventilation or lighting
# 30        80554 2015-10-30  Inadequately cleaned or sanitized food contact...
# 31        80829 2016-03-04  Moderate risk food holding temperature   [ dat...
# 32        81134 2016-01-27                   Moderate risk vermin infestation
# 33        81134 2015-10-30  Foods not protected from contamination  [ date...
# 34        81134 2015-10-30  Unclean or unsanitary food contact surfaces  [...
# 35        81134 2015-10-30  Contaminated or adulterated food  [ date viola...
# 36        81134 2015-10-30  Unclean hands or improper use of gloves  [ dat...
# 37        81134 2015-09-14            Moderate risk food holding temperature
# 38        81134 2015-09-14  Wiping cloths not clean or properly stored or ...
# 39        81134 2015-09-14  Inadequate food safety knowledge or lack of ce...
# 40        81134 2014-11-19  High risk food holding temperature   [ date vi...
# 41        81885 2015-05-01       Unclean or degraded floors walls or ceilings
# 42        81885 2015-05-01                     Improper or defective plumbing
# 43        81885 2015-05-01   Improper storage of equipment utensils or linens

# %% [markdown]
# ### Delete Violations

# %%
select_count_violation = """
SELECT COUNT(*) FROM violation"""

# %%
db.query_to_dataframe(select_count_violation)
# Out:
#    count
# 0  39907

# %%
delete_violations_for_bad_biz = """
BEGIN;
DELETE FROM violation
WHERE business_id IN ({});
COMMIT;""".format(select_invalid_business_id_where_bad_postal_code)

# %%
db.query_to_dictionary(delete_violations_for_bad_biz, fetch_res=False)

# %%
db.query_to_dataframe(select_count_violation)
# Out:
#    count
# 0  39863

# %% [markdown]
# ### Delete Inspections

# %%
select_count_inspections = """
SELECT COUNT(*) FROM inspection"""

# %%
db.query_to_dataframe(select_count_inspections)
# Out:
#    count
# 0  15429

# %%
delete_inspections_for_bad_biz = """
BEGIN;
DELETE FROM inspection
WHERE business_id IN ({});
COMMIT;""".format(select_invalid_business_id_where_bad_postal_code)

# %%
db.query_to_dictionary(delete_inspections_for_bad_biz, fetch_res=False)

# %%
db.query_to_dataframe(select_count_inspections)
# Out:
#    count
# 0  15408

# %% [markdown]
# ### Delete Businesses

# %%
db.query_to_dataframe(select_count_business)
# Out:
#    count
# 0   6161

# %%
db.query_to_dictionary(delete_invalid_business_bad_postal_code, fetch_res=False)

# %%
db.query_to_dataframe(select_count_business)
# Out:
#    count
# 0   6138

# %% [markdown]
# ### Pull Bad Postal Codes Again

# %%
db.query_to_dataframe(select_postal_code_by_postal_code_less_than_10)
# Out:
#     postal_code
# 0             0
# 1         92672
# 2         94013
# 3         94101
# 4         94120
# 5         94130
# 6         94140
# 7         94143
# 8         94513
# 9         94609
# 10        95105

# %% [markdown]
# ## Repair Bad Zip Codes
# To repair the bad zip codes, we will attempt match the nearest points using GIS.
#
# To do this, we will first need to populate the `gpnt_location` column.

# %%
db.query_to_dataframe(select_business_valid).sample(4)
# Out:
#                  address           city gpnt_location     id   latitude  \
# 1968     3614 BALBOA ST   San Francisco          None  18102  37.775728
# 288     506 VALENCIA ST   San Francisco          None   1154  37.764678
# 2345       3966 24TH ST   San Francisco          None  35464  37.751533
# 2126  845 MARKET ST FC-3  San Francisco          None  27377  37.784848
#
#        longitude                  name  phone_number  postal_code state
# 1968 -122.497701    KIM SON RESTAURANT  +14152765686      94121.0    CA
# 288  -122.421905  SUNFLOWER RESTAURANT  +14156265023      94103.0    CA
# 2345 -122.431118              BERNIE'S  +14156421192      94114.0    CA
# 2126 -122.406892               SORABOL  +14157775959      94103.0    CA

# %%
update_gpnt = """
BEGIN;
UPDATE business SET 
gpnt_location = ST_SetSRID(ST_MakePoint(latitude, longitude),4326);
COMMIT;
"""

# %%
db.query_to_dictionary(update_gpnt, fetch_res=False)

# %% [markdown]
# ### Match points to the points with bad zip codes using a given radius

# %%
db.query_to_dataframe(select_postal_code_by_postal_code_less_than_10)
# Out:
#     postal_code
# 0             0
# 1         92672
# 2         94013
# 3         94101
# 4         94120
# 5         94130
# 6         94140
# 7         94143
# 8         94513
# 9         94609
# 10        95105

# %%
def select_postal_code(postal_code):
    return """SELECT * FROM business WHERE postal_code = {}""".format(postal_code)

# %%
db.query_to_dataframe(select_postal_code(92672))
# Out:
#            address           city  \
# 0  1530 HAIGHT ST   San Francisco
#
#                                        gpnt_location     id   latitude  \
# 0  0101000020E6100000C32973F38DE242405FB87361A49C...  64660  37.769957
#
#     longitude                  name  phone_number  postal_code state
# 0 -122.447533  HAIGHT STREET MARKET  +14152550643        92672    CA

# %%
def select_gpnt_for_postal_code(postal_code):
    return """SELECT gpnt_location FROM business WHERE postal_code = {} LIMIT 1""".format(postal_code)

# %%
db.query_to_dataframe(select_gpnt_for_postal_code(92672))
# Out:
#                                        gpnt_location
# 0  0101000020E6100000C32973F38DE242405FB87361A49C...

# %%
def select_on_gpnt_radius(postal_code, distance):
    return """
            SELECT *
            FROM business
            WHERE ST_Distance_Sphere(gpnt_location, ({})) <= {}
            """.format(select_gpnt_for_postal_code(postal_code), distance)

# %%
db.query_to_dataframe(select_on_gpnt_radius(92672, 100))
# Out:
#            address           city  \
# 0  1476 HAIGHT ST   San Francisco
# 1  1509 HAIGHT ST   San Francisco
# 2   1480 HAIGHT ST  San Francisco
# 3  1535 HAIGHT ST   San Francisco
# 4  1530 HAIGHT ST   San Francisco
# 5  1599 HAIGHT ST   San Francisco
# 6  1568 HAIGHT ST   San Francisco
#
#                                        gpnt_location     id   latitude  \
# 0  0101000020E61000001BD9959691E24240193DB7D0959C...   1048  37.770068
# 1  0101000020E6100000B8AF03E78CE24240DFDDCA129D9C...   4257  37.769925
# 2  0101000020E61000001BD9959691E24240193DB7D0959C...   4896  37.770068
# 3  0101000020E6100000AD3594DA8BE2424040852348A59C...  36635  37.769893
# 4  0101000020E6100000C32973F38DE242405FB87361A49C...  64660  37.769957
# 5  0101000020E61000006DAE9AE788E24240B1FB8EE1B19C...  67587  37.769803
# 6  0101000020E61000009BCAA2B08BE242404224438EAD9C...  70970  37.769888
#
#     longitude                          name  phone_number  postal_code state
# 0 -122.446644                 CREPE EXPRESS  +14158650264        94117    CA
# 1 -122.447087                        DELUXE  +14155526949        94117    CA
# 2 -122.446644  BEN & JERRY'S HAIGHT-ASHBURY  +14154573140        94117    CA
# 3 -122.447588               BIG SLICE PIZZA  +14155522520        94117    CA
# 4 -122.447533          HAIGHT STREET MARKET  +14152550643        92672    CA
# 5 -122.448357                   BURGER URGE  +14155220122        94117    CA
# 6 -122.448093         H.Q. BAR & RESTAURANT                      94117    CA

# %%
update_92672 = """
BEGIN;
UPDATE business SET postal_code = 94117 WHERE postal_code = 92672;
COMMIT;
"""

# %%
db.query_to_dictionary(update_92672, fetch_res=False)

# %% [markdown]
# ### Check the Status of our Bad Postal Codes

# %%
db.query_to_dataframe(select_postal_code_by_postal_code_less_than_10)
# Out:
#    postal_code
# 0            0
# 1        94013
# 2        94101
# 3        94120
# 4        94130
# 5        94140
# 6        94143
# 7        94513
# 8        94609
# 9        95105

# %%
db.query_to_dataframe(select_on_gpnt_radius(94101, 100))
# Out:
#               address           city  \
# 0    1555 MISSION ST   San Francisco
# 1    1455A MARKET ST   San Francisco
# 2  1455 MARKET ST 1/F  San Francisco
# 3    1559 MISSION ST   San Francisco
# 4   41 MONTGOMERY ST   San Francisco
# 5     1400 MARKET ST   San Francisco
# 6     1408 MARKET ST   San Francisco
#
#                                        gpnt_location     id   latitude  \
# 0  0101000020E610000082C476F700E34240F06B2409C29A...   1216  37.773467
# 1  0101000020E6100000BEC1172653E34240962023A0C29A...   4661  37.775975
# 2  0101000020E61000005EB9DE3653E34240DEE68D93C29A...   5018  37.775977
# 3  0101000020E61000003B18B14F00E3424025ADF886C29A...  36745  37.773447
# 4  0101000020E6100000923B6C2233E34240C53C2B69C59A...  65856  37.774998
# 5  0101000020E61000006D54A70359E3424008C89750C19A...  66219  37.776154
# 6  0101000020E61000004A7EC4AF58E3424032755776C19A...  69121  37.776144
#
#     longitude                       name  phone_number  postal_code state
# 0 -122.418093            ZAOH RESTAURANT  +14154313930        94103    CA
# 1 -122.418129                HAPPY DONUT  +14152528868        94103    CA
# 2 -122.418126                  MCDONALDS  +14154686990        94103    CA
# 3 -122.418123  SHANGHAI CHINA RESTAURANT  +14156218188        94103    CA
# 4 -122.418299                BAMBOO ASIA  +14156246790        94101    CA
# 5 -122.418049             LITTLE GRIDDLE  +14158644292        94102    CA
# 6 -122.418058              MAVELOUS, LLC  +14156268884        94102    CA

# %% [markdown]
# ## Plot locations

# %% [markdown]
# Next, we will use Folium to plot the businesses for which we have a latitude and a longitude.

# %% [markdown]
# ### `folium.Map`
#
# To build our `folium.Map` object we will need to center the map in a given location. We will use the `avg` aggregate function to do this.

# %%
import folium

# %%
avg_location_sf = """
SELECT avg(latitude) as avg_lat, 
       avg(longitude) as avg_lon FROM ({}) q;
""".format(select_business_valid)

# %%
db.query_to_dataframe(avg_location_sf)
# Out:
#      avg_lat     avg_lon
# 0  37.774003 -122.425144

# %%
avg_loc_df = db.query_to_dataframe(avg_location_sf)
avg_loc_df
# Out:
#      avg_lat     avg_lon
# 0  37.774003 -122.425144

# %% [markdown]
# Then assign the result as a single list value.

# %%
avg_loc = avg_loc_df.values.tolist()[0]
avg_loc
# Out:
# [37.7740031665327, -122.425144254083]

# %%
sf_map = folium.Map(location=avg_loc, zoom_start=13)

# %%
within_200_meters_of_94101 = db.query_to_dataframe(select_on_gpnt_radius(94101, 200))
within_200_meters_of_94101
# Out:
#                                               address           city  \
# 0                                         28 VAN NESS  San Francisco
# 1                                    1555 MISSION ST   San Francisco
# 2                                    1601 MISSION ST   San Francisco
# 3                                    1455A MARKET ST   San Francisco
# 4                                  1455 MARKET ST 1/F  San Francisco
# 5                                     1390 MARKET ST   San Francisco
# 6                                    1559 MISSION ST   San Francisco
# 7                 GOLDEN GATE PARK, MUSIC CONCOURSE    San Francisco
# 8    GOLDEN GATE PARK, JFK DR.@CONSERVATORY OF FLO...  San Francisco
# 9                  GOLDEN GATE PARK, SPRECKLES LAKE    San Francisco
# 10                GOLDEN GATE PARK, JFK DR.@8TH AVE    San Francisco
# 11             GOLDEN GATE PARK, CAROUSEL SNACK BAR    San Francisco
# 12                                 GOLDEN GATE PARK    San Francisco
# 13                              JUSTIN HERMAN PLAZA    San Francisco
# 14                               77 VAN NESS AVE #100  San Francisco
# 15                        OFF THE GRID-UPPER HAIGHT    San Francisco
# 16              OFF THE GRID - STANYON/CIVIC CENTER    San Francisco
# 17                                           PUBLIC    San Francisco
# 18                           1390 MARKET ST SUITE 110  San Francisco
# 19                                     OFF THE GRID    San Francisco
# 20                             550 A GENE FRIEND WAY   San Francisco
# 21                                     OFF THE GRID    San Francisco
# 22                                  41 MONTGOMERY ST   San Francisco
# 23                                    1400 MARKET ST   San Francisco
# 24                                     OFF THE GRID    San Francisco
# 25                                     OFF THE GRID    San Francisco
# 26                              JUSTIN HERMAN PLAZA    San Francisco
# 27                                     OFF THE GRID    San Francisco
# 28                                     OFF THE GRID    San Francisco
# 29              MUSIC CONCOURSE IN GOLDEN GATE PARK    San Francisco
# 30                                    1408 MARKET ST   San Francisco
#
#                                         gpnt_location     id   latitude  \
# 0   0101000020E6100000D7851F9C4FE3424068588CBAD69A...   1139  37.775867
# 1   0101000020E610000082C476F700E34240F06B2409C29A...   1216  37.773467
# 2   0101000020E6100000E25817B7D1E242401D5723BBD29A...   3665  37.772025
# 3   0101000020E6100000BEC1172653E34240962023A0C29A...   4661  37.775975
# 4   0101000020E61000005EB9DE3653E34240DEE68D93C29A...   5018  37.775977
# 5   0101000020E61000001D21037976E34240535BEA20AF9A...   6636  37.777053
# 6   0101000020E61000003B18B14F00E3424025ADF886C29A...  36745  37.773447
# 7   0101000020E61000004580D3BB78E342401348895DDB9A...  60547  37.777122
# 8   0101000020E61000004580D3BB78E342401348895DDB9A...  60548  37.777122
# 9   0101000020E61000004580D3BB78E342401348895DDB9A...  60549  37.777122
# 10  0101000020E61000004580D3BB78E342401348895DDB9A...  60550  37.777122
# 11  0101000020E61000004580D3BB78E342401348895DDB9A...  60551  37.777122
# 12  0101000020E61000004580D3BB78E342401348895DDB9A...  62710  37.777122
# 13  0101000020E61000004580D3BB78E342401348895DDB9A...  63210  37.777122
# 14  0101000020E6100000562C7E5358E342407F4C6BD3D89A...  63619  37.776133
# 15  0101000020E61000004580D3BB78E342401348895DDB9A...  64319  37.777122
# 16  0101000020E61000004580D3BB78E342401348895DDB9A...  64484  37.777122
# 17  0101000020E61000004580D3BB78E342401348895DDB9A...  64738  37.777122
# 18  0101000020E61000001D21037976E34240535BEA20AF9A...  64805  37.777053
# 19  0101000020E61000004580D3BB78E342401348895DDB9A...  65266  37.777122
# 20  0101000020E61000004580D3BB78E342401348895DDB9A...  65384  37.777122
# 21  0101000020E61000004580D3BB78E342401348895DDB9A...  65479  37.777122
# 22  0101000020E6100000923B6C2233E34240C53C2B69C59A...  65856  37.774998
# 23  0101000020E61000006D54A70359E3424008C89750C19A...  66219  37.776154
# 24  0101000020E61000004580D3BB78E342401348895DDB9A...  66492  37.777122
# 25  0101000020E61000004580D3BB78E342401348895DDB9A...  66922  37.777122
# 26  0101000020E61000004580D3BB78E342401348895DDB9A...  67124  37.777122
# 27  0101000020E61000004580D3BB78E342401348895DDB9A...  67486  37.777122
# 28  0101000020E61000004580D3BB78E342401348895DDB9A...  67875  37.777122
# 29  0101000020E61000004580D3BB78E342401348895DDB9A...  68558  37.777122
# 30  0101000020E61000004A7EC4AF58E3424032755776C19A...  69121  37.776144
#
#      longitude                         name  phone_number  postal_code state
# 0  -122.419356                    MINI CAFE  +14154360177      94102.0    CA
# 1  -122.418093              ZAOH RESTAURANT  +14154313930      94103.0    CA
# 2  -122.419112                TOWER CARWASH  +14155589274      94102.0    CA
# 3  -122.418129                  HAPPY DONUT  +14152528868      94103.0    CA
# 4  -122.418126                    MCDONALDS  +14154686990      94103.0    CA
# 5  -122.416939             STARBUCKS COFFEE  +14152410256      94102.0    CA
# 6  -122.418123    SHANGHAI CHINA RESTAURANT  +14156218188      94103.0    CA
# 7  -122.419639  ANNIE'S HOT DOGS & PRETZELS                        NaN    CA
# 8  -122.419639  ANNIE'S HOT DOGS & PRETZELS                        NaN    CA
# 9  -122.419639  ANNIE'S HOT DOGS & PRETZELS                        NaN    CA
# 10 -122.419639  ANNIE'S HOT DOGS & PRETZELS  +14158610778          NaN    CA
# 11 -122.419639  ANNIE'S HOT DOGS & PRETZELS                        NaN    CA
# 12 -122.419639         SAM'S CHOWDER MOBILE  +14157120245          NaN    CA
# 13 -122.419639               LET'S BE FRANK  +14156211064          NaN    CA
# 14 -122.419484            SUBWAY SANDWICHES  +14159891866      94102.0    CA
# 15 -122.419639         LITTLEGREENCYCLO LLC  +14153951657          NaN    CA
# 16 -122.419639                TWIRL AND DIP                        NaN    CA
# 17 -122.419639                    JAPACURRY  +14152444785          NaN    CA
# 18 -122.416939               ANDERSEN BREAD  +14154297100      94102.0    CA
# 19 -122.419639   OFF THE GRID SERVICES, LLC                        NaN    CA
# 20 -122.419639                      PUBLICO  +14154370874          NaN    CA
# 21 -122.419639                    AN THE GO  +14158192000          NaN    CA
# 22 -122.418299                  BAMBOO ASIA  +14156246790      94101.0    CA
# 23 -122.418049               LITTLE GRIDDLE  +14158644292      94102.0    CA
# 24 -122.419639                PACIFIC PUFFS  +14155952052          NaN    CA
# 25 -122.419639        THE CREME BRULEE CART  +14156245414          NaN    CA
# 26 -122.419639   ALICIA'S TAMALES LOS MAYAS  +14159811493          NaN    CA
# 27 -122.419639                    PHAT THAI  +14154123331          NaN    CA
# 28 -122.419639           THE CHAIRMAN TRUCK  +14158461711          0.0    CA
# 29 -122.419639                    SLOW CITY  +14158610778          NaN    CA
# 30 -122.418058                MAVELOUS, LLC  +14156268884      94102.0    CA

# %%
near_94101_lat_long = within_200_meters_of_94101[['latitude', 'longitude','postal_code']].values.tolist()
near_94101_lat_long
# Out:
# [[37.775867, -122.419356, 94102.0],
#  [37.773467, -122.418093, 94103.0],
#  [37.772025, -122.419112, 94102.0],
#  [37.775975, -122.418129, 94103.0],
#  [37.775977, -122.418126, 94103.0],
#  [37.777053, -122.416939, 94102.0],
#  [37.773447, -122.418123, 94103.0],
#  [37.777122, -122.419639, nan],
#  [37.777122, -122.419639, nan],
#  [37.777122, -122.419639, nan],
#  [37.777122, -122.419639, nan],
#  [37.777122, -122.419639, nan],
#  [37.777122, -122.419639, nan],
#  [37.777122, -122.419639, nan],
#  [37.776133, -122.419484, 94102.0],
#  [37.777122, -122.419639, nan],
#  [37.777122, -122.419639, nan],
#  [37.777122, -122.419639, nan],
#  [37.777053, -122.416939, 94102.0],
#  [37.777122, -122.419639, nan],
#  [37.777122, -122.419639, nan],
#  [37.777122, -122.419639, nan],
#  [37.774998, -122.418299, 94101.0],
#  [37.776154, -122.418049, 94102.0],
#  [37.777122, -122.419639, nan],
#  [37.777122, -122.419639, nan],
#  [37.777122, -122.419639, nan],
#  [37.777122, -122.419639, nan],
#  [37.777122, -122.419639, 0.0],
#  [37.777122, -122.419639, nan],
#  [37.776144, -122.418058, 94102.0]]

# %%
for loc in near_94101_lat_long:
    try:
        postal_code = str(int(loc[2]))
    except:
        postal_code = None
    folium.Marker(loc[:2],postal_code).add_to(sf_map)

# %%
sf_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
